# %%
# !conda install pytorch:pytorch
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /usr/local/Caskroom/miniconda/base/envs/bitnet-cpp
#
#   added / updated specs:
#     - pytorch
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     deprecated-1.2.13          |   py39hecd8cb5_0          16 KB
#     filelock-3.17.0            |   py39hecd8cb5_0          33 KB
#     fsspec-2025.7.0            |   py39he13d532_0         542 KB
#     gmp-6.3.0                  |       h6d0c2b6_0         581 KB
#     gmpy2-2.2.1                |   py39h2cec913_0         214 KB
#     jinja2-3.1.6               |   py39hecd8cb5_0         280 KB
#     libabseil-20250127.0       | cxx17_h548131f_0         1.2 MB
#     libprotobuf-5.29.3         |       h66a43dd_1         2.8 MB
#     libtorch-2.6.0             |cpu_openblas_h4faba3d_6        48.6 MB
#     libuv-1.48.0               |       h46256e1_0         430 KB
#     llvm-openmp-17.0.6         |       hdd4a2e0_0         346 KB
#     markupsafe-3.0.2           |   py39h46256e1_0          25 KB
#     mpc-1.3.1                  |       h46256e1_0         123 KB
#     mpfr-4.2.1                 |       h46256e1_0         462 KB
#     mpmath-1.3.0               |   py39hecd8cb5_0         831 KB
#     networkx-3.2.1             |   py39hecd8cb5_0         2.4 MB
#     nomkl-3.0                  |                0          45 KB
#     numpy-2.0.1                |   py39h1d7cfa2_1          12 KB
#     numpy-base-2.0.1           |   py39h03d8c7d_1         7.3 MB
#     opentelemetry-api-1.36.0   |     pyhd8ed1ab_0          45 KB  conda-forge
#     pytorch-2.6.0              |cpu_openblas_py39hfcfd596_6        37.6 MB
#     sleef-3.5.1                |       h6c40b1e_2        1008 KB
#     sympy-1.13.3               |   py39hecd8cb5_1        11.2 MB
#     wrapt-1.17.0               |   py39h46256e1_0          51 KB
#     ------------------------------------------------------------
#                                            Total:       115.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-64::blas-1.0-openblas
#   deprecated         pkgs/main/osx-64::deprecated-1.2.13-py39hecd8cb5_0
#   filelock           pkgs/main/osx-64::filelock-3.17.0-py39hecd8cb5_0
#   fsspec             pkgs/main/osx-64::fsspec-2025.7.0-py39he13d532_0
#   gmp                pkgs/main/osx-64::gmp-6.3.0-h6d0c2b6_0
#   gmpy2              pkgs/main/osx-64::gmpy2-2.2.1-py39h2cec913_0
#   jinja2             pkgs/main/osx-64::jinja2-3.1.6-py39hecd8cb5_0
#   libabseil          pkgs/main/osx-64::libabseil-20250127.0-cxx17_h548131f_0
#   libgfortran        pkgs/main/osx-64::libgfortran-5.0.0-11_3_0_hecd8cb5_28
#   libgfortran5       pkgs/main/osx-64::libgfortran5-11.3.0-h9dfd629_28
#   libopenblas        pkgs/main/osx-64::libopenblas-0.3.29-h3f8574a_0
#   libprotobuf        pkgs/main/osx-64::libprotobuf-5.29.3-h66a43dd_1
#   libtorch           pkgs/main/osx-64::libtorch-2.6.0-cpu_openblas_h4faba3d_6
#   libuv              pkgs/main/osx-64::libuv-1.48.0-h46256e1_0
#   llvm-openmp        pkgs/main/osx-64::llvm-openmp-17.0.6-hdd4a2e0_0
#   markupsafe         pkgs/main/osx-64::markupsafe-3.0.2-py39h46256e1_0
#   mpc                pkgs/main/osx-64::mpc-1.3.1-h46256e1_0
#   mpfr               pkgs/main/osx-64::mpfr-4.2.1-h46256e1_0
#   mpmath             pkgs/main/osx-64::mpmath-1.3.0-py39hecd8cb5_0
#   networkx           pkgs/main/osx-64::networkx-3.2.1-py39hecd8cb5_0
#   nomkl              pkgs/main/osx-64::nomkl-3.0-0
#   numpy              pkgs/main/osx-64::numpy-2.0.1-py39h1d7cfa2_1
#   numpy-base         pkgs/main/osx-64::numpy-base-2.0.1-py39h03d8c7d_1
#   opentelemetry-api  conda-forge/noarch::opentelemetry-api-1.36.0-pyhd8ed1ab_0
#   pytorch            pkgs/main/osx-64::pytorch-2.6.0-cpu_openblas_py39hfcfd596_6
#   sleef              pkgs/main/osx-64::sleef-3.5.1-h6c40b1e_2
#   sympy              pkgs/main/osx-64::sympy-1.13.3-py39hecd8cb5_1
#   wrapt              pkgs/main/osx-64::wrapt-1.17.0-py39h46256e1_0
#
#
# Proceed ([y]/n)? ^C

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import pennylane as qml
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torchvision
#
# File /usr/local/Caskroom/miniconda/base/envs/bitnet-cpp/lib/python3.9/site-packages/torch/__init__.py:405
#     403     if USE_GLOBAL_DEPS:
#     404         _load_global_deps()
# --> 405     from torch._C import *  # noqa: F403
#     408 class SymInt:
#     409     """
#     410     Like an int (including magic methods), but redirects all operations on the
#     411     wrapped node. This is used in particular to symbolically record operations
#     412     in the symbolic shape workflow.
#     413     """
#
# ImportError: dlopen(/usr/local/Caskroom/miniconda/base/envs/bitnet-cpp/lib/python3.9/site-packages/torch/_C.cpython-39-darwin.so, 0x0002): Symbol not found: __ZN2at3cpu19is_cpu_support_vnniEv
#   Referenced from: <6CB41E0C-65D2-39DB-9F32-D8537790DD07> /usr/local/Caskroom/miniconda/base/envs/bitnet-cpp/lib/python3.9/site-packages/torch/lib/libtorch_python.dylib
#   Expected in:     <078DF3B7-D63C-3CEF-94C1-C063C5E5A468> /usr/local/Caskroom/miniconda/base/envs/bitnet-cpp/lib/libtorch_cpu.dylib

# %%
# Load CIFAR-10 sample
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True)
images, labels = next(iter(trainloader))

# %%
# Define quantum device
dev = qml.device("braket.aws.qubit", 
                 device_arn="arn:aws:braket:::device/quantum-simulator/amazon/sv1", 
                 wires=4)

# %%
# Quantum circuit
@qml.qnode(dev, interface="torch")
def quantum_circuit(inputs, weights):
    for i in range(4):
        qml.RY(inputs[i], wires=i)
    for i in range(4):
        qml.RZ(weights[i], wires=i)
    for i in range(3):
        qml.CNOT(wires=[i, i+1])
    for i in range(4):
        qml.RY(weights[i+4], wires=i)
    return [qml.expval(qml.PauliZ(i)) for i in range(4)]

# %%
# Hybrid CNN + Quantum model
class HybridModel(nn.Module):
    def __init__(self):
        super(HybridModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 8, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(8, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 4)
        self.quantum_layer = qml.qnn.TorchLayer(quantum_circuit, {"weights": (8,)})
        self.fc2 = nn.Linear(4, 10)
    
    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = torch.tanh(self.fc1(x))
        x = self.quantum_layer(x)
        x = self.fc2(x)
        return x

# %%
# Forward pass
model = HybridModel()
output = model(images)

print(f"Input shape: {images.shape}")
print(f"Output shape: {output.shape}")
print(f"Output:\n{output}")
