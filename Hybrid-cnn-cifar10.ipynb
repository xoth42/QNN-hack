# %% [markdown]
# # Hybrid CNN + Quantum Neural Network for CIFAR-10
# Implements a density QNN architecture based on the paper's framework

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import pennylane as qml
import numpy as np

# %% [markdown]
# ## Environment Setup
# Load AWS configuration from .env file

# %%
import os
from dotenv import load_dotenv
from IPython.display import clear_output

# Load environment variables from .env file
load_dotenv()

# Function to safely get and mask sensitive environment variables
def get_masked_env(var_name):
    value = os.getenv(var_name, '')
    if value and var_name in ['AWS_ACCESS_KEY_ID', 'AWS_SECRET_ACCESS_KEY']:
        return value[:4] + '*' * (len(value) - 8) + value[-4:]
    return value

# Display current configuration
print("Current AWS Configuration:")
print(f"Region: {get_masked_env('AWS_DEFAULT_REGION')}")
print(f"Access Key ID: {get_masked_env('AWS_ACCESS_KEY_ID')}")
print(f"Secret Access Key: {get_masked_env('AWS_SECRET_ACCESS_KEY')}")
print(f"Braket Device: {get_masked_env('BRAKET_DEVICE')}")

# Function to update AWS configuration
def update_aws_config(region=None, access_key=None, secret_key=None, device_arn=None):
    if region:
        os.environ['AWS_DEFAULT_REGION'] = region
    if access_key:
        os.environ['AWS_ACCESS_KEY_ID'] = access_key
    if secret_key:
        os.environ['AWS_SECRET_ACCESS_KEY'] = secret_key
    if device_arn:
        os.environ['BRAKET_DEVICE'] = device_arn
    
    clear_output()
    print("Updated AWS Configuration:")
    print(f"Region: {get_masked_env('AWS_DEFAULT_REGION')}")
    print(f"Access Key ID: {get_masked_env('AWS_ACCESS_KEY_ID')}")
    print(f"Secret Access Key: {get_masked_env('AWS_SECRET_ACCESS_KEY')}")
    print(f"Braket Device: {get_masked_env('BRAKET_DEVICE')}")

# Install python-dotenv if not already installed
try:
    import dotenv
except ImportError:
    # !pip install python-dotenv

# %%
# Load CIFAR-10 sample
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True)
images, labels = next(iter(trainloader))

print(f"Loaded batch: {images.shape}")
# Out:
# Files already downloaded and verified
# Loaded batch: torch.Size([4, 3, 32, 32])

# %%
# Amazon Braket SV1 simulator device
dev = qml.device(
    "braket.aws.qubit",
    device_arn=os.getenv('BRAKET_DEVICE'),
    wires=4,
    shots=1000
)
# Out:
# ---------------------------------------------------------------------------
# NoRegionError                             Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Amazon Braket SV1 simulator device
# ----> 2 dev = qml.device(
#       3     "braket.aws.qubit",
#       4     device_arn="arn:aws:braket:::device/quantum-simulator/amazon/sv1",
#       5     wires=4,
#       6     shots=1000
#       7 )
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/pennylane/devices/device_constructor.py:264, in device(name, *args, **kwargs)
#     258         raise DeviceError(
#     259             f"The {name} plugin requires PennyLane versions {required_versions}, "
#     260             f"however PennyLane version {qml.version()} is installed."
#     261         )
#     263 # Construct the device
# --> 264 dev = plugin_device_class(*args, **options)
#     266 # Once the device is constructed, we set its custom expansion function if
#     267 # any custom decompositions were specified.
#     268 if custom_decomps is not None:
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/braket/pennylane_plugin/braket_device.py:670, in BraketAwsQubitDevice.__init__(self, wires, device_arn, s3_destination_folder, shots, poll_timeout_seconds, poll_interval_seconds, aws_session, max_connections, max_retries, **run_kwargs)
#     656 def __init__(
#     657     self,
#     658     wires: int | Iterable,
#    (...)    668     **run_kwargs,
#     669 ):
# --> 670     device = AwsDevice(device_arn, aws_session=aws_session)
#     671     user_agent = f"BraketPennylanePlugin/{__version__}"
#     672     device.aws_session.add_braket_user_agent(user_agent)
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/braket/aws/aws_device.py:117, in AwsDevice.__init__(self, arn, aws_session, noise_model)
#     115 self._poll_interval_seconds = None
#     116 self._type = None
# --> 117 self._aws_session = self._get_session_and_initialize(aws_session or AwsSession())
#     118 self._ports = None
#     119 self._frames = None
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/braket/aws/aws_session.py:95, in AwsSession.__init__(self, boto_session, braket_client, config, default_bucket)
#      91 else:
#      92     self.boto_session = boto_session or boto3.Session(
#      93         region_name=os.environ.get("AWS_REGION")
#      94     )
# ---> 95     self.braket_client = self.boto_session.client(
#      96         "braket", config=self._config, endpoint_url=os.environ.get("BRAKET_ENDPOINT")
#      97     )
#      98 self._braket_user_agents = self._config._user_provided_options["user_agent_extra"]
#      99 self._custom_default_bucket = bool(default_bucket)
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/boto3/session.py:337, in Session.client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config, aws_account_id)
#     332 if aws_account_id is None:
#     333     # Remove aws_account_id for arbitrary
#     334     # botocore version mismatches in AWS Lambda.
#     335     del create_client_kwargs['aws_account_id']
# --> 337 return self._session.create_client(
#     338     service_name, **create_client_kwargs
#     339 )
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/botocore/session.py:1031, in Session.create_client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config, aws_account_id)
#    1016 user_agent_creator.set_client_features(get_context().features)
#    1018 client_creator = botocore.client.ClientCreator(
#    1019     loader,
#    1020     endpoint_resolver,
#    (...)   1029     auth_token_resolver=self.get_auth_token,
#    1030 )
# -> 1031 client = client_creator.create_client(
#    1032     service_name=service_name,
#    1033     region_name=region_name,
#    1034     is_secure=use_ssl,
#    1035     endpoint_url=endpoint_url,
#    1036     verify=verify,
#    1037     credentials=credentials,
#    1038     scoped_config=self.get_scoped_config(),
#    1039     client_config=config,
#    1040     api_version=api_version,
#    1041     auth_token=auth_token,
#    1042 )
#    1043 monitor = self._get_internal_component('monitor')
#    1044 if monitor is not None:
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/botocore/client.py:157, in ClientCreator.create_client(self, service_name, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, api_version, client_config, auth_token)
#     153 if token := self._evaluate_client_specific_token(
#     154     service_model.signing_name
#     155 ):
#     156     auth_token = token
# --> 157 client_args = self._get_client_args(
#     158     service_model,
#     159     region_name,
#     160     is_secure,
#     161     endpoint_url,
#     162     verify,
#     163     credentials,
#     164     scoped_config,
#     165     client_config,
#     166     endpoint_bridge,
#     167     auth_token,
#     168     endpoints_ruleset_data,
#     169     partition_data,
#     170 )
#     171 service_client = cls(**client_args)
#     172 self._register_retries(service_client)
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/botocore/client.py:557, in ClientCreator._get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge, auth_token, endpoints_ruleset_data, partition_data)
#     533 def _get_client_args(
#     534     self,
#     535     service_model,
#    (...)    546     partition_data,
#     547 ):
#     548     args_creator = ClientArgsCreator(
#     549         self._event_emitter,
#     550         self._user_agent,
#    (...)    555         user_agent_creator=self._user_agent_creator,
#     556     )
# --> 557     return args_creator.get_client_args(
#     558         service_model,
#     559         region_name,
#     560         is_secure,
#     561         endpoint_url,
#     562         verify,
#     563         credentials,
#     564         scoped_config,
#     565         client_config,
#     566         endpoint_bridge,
#     567         auth_token,
#     568         endpoints_ruleset_data,
#     569         partition_data,
#     570     )
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/botocore/args.py:121, in ClientArgsCreator.get_client_args(self, service_model, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, client_config, endpoint_bridge, auth_token, endpoints_ruleset_data, partition_data)
#     106 def get_client_args(
#     107     self,
#     108     service_model,
#    (...)    119     partition_data=None,
#     120 ):
# --> 121     final_args = self.compute_client_args(
#     122         service_model,
#     123         client_config,
#     124         endpoint_bridge,
#     125         region_name,
#     126         endpoint_url,
#     127         is_secure,
#     128         scoped_config,
#     129     )
#     131     service_name = final_args['service_name']  # noqa
#     132     parameter_validation = final_args['parameter_validation']
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/botocore/args.py:259, in ClientArgsCreator.compute_client_args(self, service_model, client_config, endpoint_bridge, region_name, endpoint_url, is_secure, scoped_config)
#     256 if configured_endpoint_url is not None:
#     257     register_feature_id('ENDPOINT_OVERRIDE')
# --> 259 endpoint_config = self._compute_endpoint_config(
#     260     service_name=service_name,
#     261     region_name=region_name,
#     262     endpoint_url=configured_endpoint_url,
#     263     is_secure=is_secure,
#     264     endpoint_bridge=endpoint_bridge,
#     265     s3_config=s3_config,
#     266 )
#     267 endpoint_variant_tags = endpoint_config['metadata'].get('tags', [])
#     269 # Some third-party libraries expect the final user-agent string in
#     270 # ``client.meta.config.user_agent``. To maintain backwards
#     271 # compatibility, the preliminary user-agent string (before any Config
#     272 # object modifications and without request-specific user-agent
#     273 # components) is stored in the new Config object's ``user_agent``
#     274 # property but not used by Botocore itself.
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/botocore/args.py:447, in ClientArgsCreator._compute_endpoint_config(self, service_name, region_name, endpoint_url, is_secure, endpoint_bridge, s3_config)
#     445 if service_name == 'sts':
#     446     return self._compute_sts_endpoint_config(**resolve_endpoint_kwargs)
# --> 447 return self._resolve_endpoint(**resolve_endpoint_kwargs)
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/botocore/args.py:552, in ClientArgsCreator._resolve_endpoint(self, service_name, region_name, endpoint_url, is_secure, endpoint_bridge)
#     544 def _resolve_endpoint(
#     545     self,
#     546     service_name,
#    (...)    550     endpoint_bridge,
#     551 ):
# --> 552     return endpoint_bridge.resolve(
#     553         service_name, region_name, endpoint_url, is_secure
#     554     )
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/botocore/client.py:671, in ClientEndpointBridge.resolve(self, service_name, region_name, endpoint_url, is_secure)
#     665 use_dualstack_endpoint = self._resolve_use_dualstack_endpoint(
#     666     service_name
#     667 )
#     668 use_fips_endpoint = self._resolve_endpoint_variant_config_var(
#     669     'use_fips_endpoint'
#     670 )
# --> 671 resolved = self.endpoint_resolver.construct_endpoint(
#     672     service_name,
#     673     region_name,
#     674     use_dualstack_endpoint=use_dualstack_endpoint,
#     675     use_fips_endpoint=use_fips_endpoint,
#     676 )
#     678 # If we can't resolve the region, we'll attempt to get a global
#     679 # endpoint for non-regionalized services (iam, route53, etc)
#     680 if not resolved:
#     681     # TODO: fallback partition_name should be configurable in the
#     682     # future for users to define as needed.
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/botocore/regions.py:233, in EndpointResolver.construct_endpoint(self, service_name, region_name, partition_name, use_dualstack_endpoint, use_fips_endpoint)
#     228 if use_dualstack_endpoint and (
#     229     partition['partition']
#     230     in self._UNSUPPORTED_DUALSTACK_PARTITIONS
#     231 ):
#     232     continue
# --> 233 result = self._endpoint_for_partition(
#     234     partition,
#     235     service_name,
#     236     region_name,
#     237     use_dualstack_endpoint,
#     238     use_fips_endpoint,
#     239 )
#     240 if result:
#     241     return result
#
# File /usr/local/Caskroom/miniconda/base/envs/cnn4/lib/python3.11/site-packages/botocore/regions.py:281, in EndpointResolver._endpoint_for_partition(self, partition, service_name, region_name, use_dualstack_endpoint, use_fips_endpoint, force_partition)
#     279         region_name = service_data['partitionEndpoint']
#     280     else:
# --> 281         raise NoRegionError()
#     283 resolve_kwargs = {
#     284     'partition': partition,
#     285     'service_name': service_name,
#    (...)    289     'use_fips_endpoint': use_fips_endpoint,
#     290 }
#     292 # Attempt to resolve the exact region for this partition.
#
# NoRegionError: You must specify a region.

# %%
# Density QNN: Sub-unitary quantum circuit (RBS-based)
@qml.qnode(dev, interface="torch")
def quantum_sub_circuit(inputs, weights):
    # Data encoding
    for i in range(4):
        qml.RY(inputs[i], wires=i)
    
    # Parameterized RBS-inspired gates
    for i in range(4):
        qml.RZ(weights[i], wires=i)
    
    # Entanglement (CNOT ladder)
    for i in range(3):
        qml.CNOT(wires=[i, i+1])
    
    # Second rotation layer
    for i in range(4):
        qml.RY(weights[i+4], wires=i)
    
    return [qml.expval(qml.PauliZ(i)) for i in range(4)]

# %%
# Hybrid CNN + Density Quantum Model
class HybridDensityQNN(nn.Module):
    def __init__(self, num_sub_unitaries=2):
        super(HybridDensityQNN, self).__init__()
        
        # CNN feature extractor
        self.conv1 = nn.Conv2d(3, 8, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(8, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 4)
        
        # Density QNN: K sub-unitaries with independent parameters
        self.K = num_sub_unitaries
        self.quantum_layers = nn.ModuleList([
            qml.qnn.TorchLayer(quantum_sub_circuit, {"weights": (8,)})
            for _ in range(self.K)
        ])
        
        # Trainable mixing coefficients α_k (ensure sum to 1 via softmax)
        self.alpha = nn.Parameter(torch.ones(self.K))
        
        # Final classifier
        self.fc2 = nn.Linear(4, 10)
    
    def forward(self, x):
        # CNN feature extraction
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = torch.tanh(self.fc1(x))
        
        # Density QNN: weighted sum of sub-unitaries
        alpha_norm = torch.softmax(self.alpha, dim=0)
        quantum_out = sum(alpha_norm[k] * self.quantum_layers[k](x) for k in range(self.K))
        
        # Classification
        out = self.fc2(quantum_out)
        return out

# %%
# Initialize and test forward pass
model = HybridDensityQNN(num_sub_unitaries=2)
output = model(images)

print(f"Input shape: {images.shape}")
print(f"Output shape: {output.shape}")
print(f"Mixing coefficients α: {torch.softmax(model.alpha, dim=0).detach()}")
print(f"\nOutput logits:\n{output}")
